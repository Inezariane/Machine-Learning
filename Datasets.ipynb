# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from matplotlib import style
import matplotlib.pyplot as plt


df=pd.read_csv("vehicles.csv")
df.head()
# Out:
#    Unnamed: 0                vin manufacturer  year            color  \
# 0           0  KNEQQMPI59JQMQFUS   Volkswagen  2023   metallic_black
# 1           1  Y06254A9NYNT183XI         Audi  2021      matte_black
# 2           2  U8J8TBA70SBBGVXT1       Nissan  2020  metallic_silver
# 3           3  ZWEG0R44V9S72T8CO    Chevrolet  2012             gray
# 4           4  XRNFVKZUXQ4WJHJTK       Nissan  2009           purple
#
#      body_type engine_type transmission  fuel_type  seating_capacity  \
# 0        Truck    electric       manual   gasoline                 6
# 1  Convertible      diesel    automatic     hybrid                10
# 2        Wagon      petrol       manual  biodiesel                 3
# 3          Van      petrol    automatic    ethanol                 6
# 4    Hatchback      petrol       manual   gasoline                10
#
#    kilometers_driven vehicle_condition_status  selling_price  \
# 0              19.84                 inactive        5980.16
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                vin manufacturer  year            color  \
# 499741      499741  CQKFTDB3PATH31NRK         Ford  2018           silver
# 499742      499742  XV0S95MH6Q96UT9V1          BMW  2018            green
# 499743      499743  FU6BSORX4Z369WJTM       Nissan  2005   metallic_brown
# 499744      499744  OQBLQCK353L8VXN5I        Honda  2020  metallic_silver
# 499745      499745  K1YXRQOWFRG2M351R          BMW  2012    metallic_gray
#
#         body_type engine_type transmission fuel_type  seating_capacity  \
# 499741  Hatchback      diesel       manual  hydrogen                10
# 499742      Truck    electric    automatic   ethanol                 5
# 499743      Coupe      petrol    automatic   ethanol                 8
# 499744      Truck      diesel       manual  electric                 4
# 499745      Coupe    electric    automatic    diesel                 3
#
#         kilometers_driven vehicle_condition_status  selling_price  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0           year  seating_capacity  kilometers_driven  \
# count  499746.000000  499746.000000     499746.000000      499746.000000
# mean   249872.500000    2011.995770          5.999532         120.362064
# std    144264.388151       7.204957          2.583512         108.449333
# min         0.000000    2000.000000          2.000000           0.000000
# 25%    124936.250000    2006.000000          4.000000          30.730000
# 50%    249872.500000    2012.000000          6.000000          89.290000
# 75%    374808.750000    2018.000000          8.000000         185.150000
# max    499745.000000    2024.000000         10.000000         479.980000
#
#        selling_price      owner_age  proposed_purchase_price
# count  499746.000000  499746.000000            499746.000000
# mean    17658.561496      59.013005             19425.720447
# std      7580.377670      23.933346              8358.384150
# min      4500.000000      18.000000              4725.020000
# ...

# %%
df.shape
# Out:
# (499746, 19)

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# Unnamed: 0
# 499745    1
# 0         1
# 499729    1
# 499728    1
# 499727    1
#          ..
# 6         1
# 5         1
# 4         1
# 3         1
# 2         1
# Name: count, Length: 499746, dtype: int64
# vin
# K1YXRQOWFRG2M351R    1
# KNEQQMPI59JQMQFUS    1
# F065HQH04AWR13K89    1
# 64CLC7FF68T5ZZ2HH    1
# MJC31MNO5KNFZLIG0    1
#                     ..
# HNHT7ZUBJ23KZDIV1    1
# 1LO3MRZOB4X3Y1KST    1
# XRNFVKZUXQ4WJHJTK    1
# ZWEG0R44V9S72T8CO    1
# U8J8TBA70SBBGVXT1    1
# Name: count, Length: 499746, dtype: int64
# manufacturer
# Audi          50272
# Honda         50244
# Ford          50138
# Chevrolet     50138
# Mercedes      49925
# Nissan        49880
# Hyundai       49876
# BMW           49817
# Toyota        49755
# Volkswagen    49701
# Name: count, dtype: int64
# year
# 2016    20365
# 2008    20285
# 2018    20101
# 2001    20094
# 2014    20082
# 2017    20055
# 2015    20052
# 2023    20043
# 2006    20015
# 2010    20013
# 2003    19990
# 2002    19989
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'vin',
#  'manufacturer',
#  'year',
#  'color',
#  'body_type',
#  'engine_type',
#  'transmission',
#  'fuel_type',
#  'seating_capacity',
#  'kilometers_driven',
#  'vehicle_condition_status',
#  'selling_price',
#  'owner_name',
#  'owner_profession',
#  'owner_age',
#  'owner_district',
#  'proposed_purchase_price',
#  'purchase_date']

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'vin',
#  'manufacturer',
#  'year',
#  'color',
#  'body_type',
#  'engine_type',
#  'transmission',
#  'fuel_type',
#  'seating_capacity',
#  'kilometers_driven',
#  'vehicle_condition_status',
#  'selling_price',
#  'owner_name',
#  'owner_profession',
#  'owner_age',
#  'owner_district',
#  'proposed_purchase_price',
#  'purchase_date']

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# vin                          object
# manufacturer                 object
# year                          int64
# color                        object
# body_type                    object
# engine_type                  object
# transmission                 object
# fuel_type                    object
# seating_capacity              int64
# kilometers_driven           float64
# vehicle_condition_status     object
# selling_price               float64
# owner_name                   object
# owner_profession             object
# owner_age                     int64
# owner_district               object
# proposed_purchase_price     float64
# purchase_date                object
# dtype: object

# %%
df.nunique()
# Out:
# Unnamed: 0                  499746
# vin                         499746
# manufacturer                    10
# year                            25
# color                           23
# body_type                        8
# engine_type                      3
# transmission                     2
# fuel_type                        7
# seating_capacity                 9
# kilometers_driven            44561
# vehicle_condition_status         2
# selling_price               356474
# owner_name                     139
# owner_profession                89
# owner_age                       83
# owner_district                  30
# proposed_purchase_price     458928
# purchase_date                 8400
# dtype: int64

# %%
# Display unique values for categorical columns
categorical_columns = df.select_dtypes(include=["object"]).columns
for col in categorical_columns:
    unique_values = df[col].unique()
    print(f"{col}: {len(unique_values)}")
# Out:
# vin: 499746
# manufacturer: 10
# color: 23
# body_type: 8
# engine_type: 3
# transmission: 2
# fuel_type: 7
# vehicle_condition_status: 2
# owner_name: 139
# owner_profession: 89
# owner_district: 30
# purchase_date: 8400

# %%
df.drop(['owner_name','vin'], axis=1, inplace=True)

# %%
df["proposed_purchase_price"] = pd.to_numeric(df["proposed_purchase_price"], errors="coerce", downcast="float")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# A stacked KDE plot is a type of data visualization that combines multiple Kernel Density Estimate (KDE) plots into a single graph,
# where each KDE is stacked on top of the others.
# This allows for easy comparison of the distributions of different groups within a dataset.
g = sns.FacetGrid(df, hue='transmission', height=5, aspect=2, xlim=(df["proposed_purchase_price"].min(),df["proposed_purchase_price"].max())) #
# Map the KDE plot
g.map(sns.kdeplot, 'proposed_purchase_price', fill=True)
g.add_legend(title='Purchase Price')
g.set_axis_labels('Purchase Price', 'Density')
g.fig.suptitle('KDE of Purchase Price by transmission', fontsize=16)
plt.show()

# %%
df.head().T
# Out:
#                                        0              1                2  \
# Unnamed: 0                             0              1                2
# manufacturer                  Volkswagen           Audi           Nissan
# year                                2023           2021             2020
# color                     metallic_black    matte_black  metallic_silver
# body_type                          Truck    Convertible            Wagon
# engine_type                     electric         diesel           petrol
# transmission                      manual      automatic           manual
# fuel_type                       gasoline         hybrid        biodiesel
# seating_capacity                       6             10                3
# kilometers_driven                  19.84          19.83            78.73
# vehicle_condition_status        inactive         active         inactive
# selling_price                    5980.16        8778.19          8921.27
# ...

# %%
df.tail().T
# Out:
#                                  499741          499742           499743  \
# Unnamed: 0                       499741          499742           499743
# manufacturer                       Ford             BMW           Nissan
# year                               2018            2018             2005
# color                            silver           green   metallic_brown
# body_type                     Hatchback           Truck            Coupe
# engine_type                      diesel        electric           petrol
# transmission                     manual       automatic        automatic
# fuel_type                      hydrogen         ethanol          ethanol
# seating_capacity                     10               5                8
# kilometers_driven                 73.91           71.52           314.64
# vehicle_condition_status       inactive          active         inactive
# selling_price                  10926.09        12021.33          26053.9
# ...

# %%
sdf = df[['manufacturer','year','color','body_type','engine_type']]
sdf.describe()
# Out:
#                 year
# count  499746.000000
# mean     2011.995770
# std         7.204957
# min      2000.000000
# 25%      2006.000000
# 50%      2012.000000
# 75%      2018.000000
# max      2024.000000

# %%
df_bfr_2021=sdf[sdf['year']<2021]
df_bfr_2021.describe()
# Out:
#                 year
# count  420050.000000
# mean     2010.003285
# std         6.052228
# min      2000.000000
# 25%      2005.000000
# 50%      2010.000000
# 75%      2015.000000
# max      2020.000000

# %%
fdf= df['purchase_date'][:10]
fdf.shape
# Out:
# (10,)

# %%
df['proposed_purchase_price'].plot.hist(bins=30, alpha=0.7, color='blue')
plt.show()

# %%
data = [140, 189, 185, 195, 149, 189, 147, 154, 174, 169, 195,
        159, 192, 155, 191, 153, 157, 140, 144, 140, 172, 157,
        181, 182, 166, 167,140,140]

n = len(data)

k = int(np.ceil(np.log2(n) + 1))

unique_values, counts = np.unique(data, return_counts=True)

plt.figure(figsize=(23, 3))

plt.hist(data, bins=k, edgecolor="yellow", color="violet")
#plt.xticks(unique_values)
plt.show()

# %%
pd.crosstab(df.year , df.manufacturer)
# Out:
# manufacturer  Audi   BMW  Chevrolet  Ford  Honda  Hyundai  Mercedes  Nissan  \
# year
# 2000          2014  1966       2068  1951   2011     2007      1977    1993
# 2001          1976  2030       1951  2001   1974     2013      2068    1985
# 2002          2056  1929       2088  1954   2039     1953      1970    2023
# 2003          2036  2015       2048  1976   1963     1931      2071    2031
# 2004          2022  2042       2053  2000   1992     1938      2011    1988
# 2005          1979  1958       2069  1957   2058     2050      1977    1948
# 2006          2044  2013       1984  2088   2027     1889      1945    1931
# 2007          2032  2021       1971  2006   1982     2000      2042    1913
# 2008          2056  2003       2080  1945   2053     2045      2006    1991
# 2009          1994  2026       1992  1994   1991     2007      1956    1964
# 2010          2046  2054       2043  2044   1936     1940      2000    1998
# ...

# %%
ax=pd.crosstab(df.year, df.manufacturer).plot(kind= "barh", figsize= (20,70));
plt.show()

# %%
ct = df[df["year"]>2020]
pd.crosstab(ct.year, ct.manufacturer)
# Out:
# manufacturer  Audi   BMW  Chevrolet  Ford  Honda  Hyundai  Mercedes  Nissan  \
# year
# 2021          1989  1927       2012  2027   1962     2030      1998    1952
# 2022          2004  1968       2045  1999   2071     1896      2023    1976
# 2023          2031  1991       1956  1940   2025     2017      2036    1991
# 2024          1939  1920       1938  1971   2009     2001      1983    1968
#
# manufacturer  Toyota  Volkswagen
# year
# 2021            2008        2044
# 2022            1979        1967
# 2023            2126        1930
# 2024            1992        2055

# %%
ct = df[df["owner_age"]>30]
pd.crosstab(ct.owner_age, ct.body_type)
# Out:
# body_type  Convertible  Coupe  Hatchback  SUV  Sedan  Truck  Van  Wagon
# owner_age
# 31                 747    728        739  762    783    720  729    735
# 32                 776    747        753  722    774    719  744    774
# 33                 699    723        750  731    788    759  768    723
# 34                 731    756        726  722    763    775  769    760
# 35                 779    726        730  768    752    788  774    752
# ...                ...    ...        ...  ...    ...    ...  ...    ...
# 96                 744    726        737  743    781    715  714    761
# 97                 764    707        739  778    758    758  771    755
# 98                 781    753        699  742    749    770  728    752
# 99                 787    790        754  712    756    755  743    745
# 100                744    794        738  808    771    735  750    758
#
# [70 rows x 8 columns]

# %%
pd.crosstab(ct.seating_capacity, ct.manufacturer)
# Out:
# manufacturer      Audi   BMW  Chevrolet  Ford  Honda  Hyundai  Mercedes  \
# seating_capacity
# 2                 4707  4704       4730  4494   4822     4773      4769
# 3                 4631  4620       4652  4712   4748     4654      4676
# 4                 4734  4692       4755  4814   4620     4741      4614
# 5                 4753  4655       4574  4645   4706     4736      4709
# 6                 4702  4542       4661  4710   4706     4666      4642
# 7                 4684  4622       4778  4812   4746     4582      4653
# 8                 4625  4909       4674  4700   4659     4652      4652
# 9                 4782  4640       4612  4747   4587     4535      4718
# 10                4843  4755       4791  4678   4707     4775      4599
#
# manufacturer      Nissan  Toyota  Volkswagen
# seating_capacity
# 2                   4646    4694        4551
# 3                   4730    4759        4737
# 4                   4741    4745        4640
# ...

# %%
ax = pd.crosstab(ct.seating_capacity, ct.manufacturer).plot(kind="bar", figsize = (20,4));

for p in ax.patches:
    count = int(p.get_height())
    ax.annotate(f'{count}', (p.get_x() + p.get_width() / 2, count), ha='center', va='bottom', fontsize=12, color='green', rotation=90)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ax = pd.crosstab(ct.seating_capacity, ct.manufacturer).plot(kind="bar", figsize = (20,4));
#       3 for p in ax.patches:
#       4     count = int(p.get_height())
#
# NameError: name 'ct' is not defined

# %%
x = df["selling_price"][:30]
y = df["proposed_purchase_price"][:30]

plt.figure(figsize=(23,7))
plt.scatter(x, y, color='red', alpha=0.5, edgecolors='b', linewidth=2)
plt.title('Scatter Plot of Proposed Purchase')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby('manufacturer')['selling_price'].max()
# Out:
# manufacturer
# Audi          31899.85
# BMW           31899.82
# Chevrolet     31899.95
# Ford          31899.40
# Honda         31899.54
# Hyundai       31899.89
# Mercedes      31898.80
# Nissan        31899.99
# Toyota        31899.00
# Volkswagen    31899.92
# Name: selling_price, dtype: float64

# %%
df.groupby('manufacturer')[['selling_price', 'proposed_purchase_price']].sum()
# Out:
#               selling_price  proposed_purchase_price
# manufacturer
# Audi           8.889681e+08             9.778801e+08
# BMW            8.828390e+08             9.712355e+08
# Chevrolet      8.892914e+08             9.782520e+08
# Ford           8.832898e+08             9.718546e+08
# Honda          8.850742e+08             9.736768e+08
# Hyundai        8.791838e+08             9.671245e+08
# Mercedes       8.822122e+08             9.705080e+08
# Nissan         8.791842e+08             9.671946e+08
# Toyota         8.779599e+08             9.658786e+08
# Volkswagen     8.767928e+08             9.643214e+08

# %%
df.groupby(['transmission','manufacturer','fuel_type'])[['selling_price', 'proposed_purchase_price']].sum()
# Out:
#                                      selling_price  proposed_purchase_price
# transmission manufacturer fuel_type
# automatic    Audi         biodiesel    64456047.57              70879042.85
#                           diesel       62189927.69              68424975.77
#                           electric     64040434.32              70478067.15
#                           ethanol      64258342.01              70730775.58
#                           gasoline     63902234.54              70239847.24
# ...                                            ...                      ...
# manual       Volkswagen   electric     62534748.07              68760329.05
#                           ethanol      63398527.42              69735573.31
#                           gasoline     61595373.93              67750480.85
#                           hybrid       62883156.59              69150082.43
#                           hydrogen     61745281.74              67900677.50
#
# ...

# %%
df.groupby(['manufacturer', 'fuel_type']).agg({
    'seating_capacity': ['min', 'max', 'mean', 'std', 'first', 'last'],
    'selling_price': ['min', 'max', 'mean', 'std', 'sum'],
    'proposed_purchase_price': ['min', 'max', 'mean', 'std', 'sum']
})
# Out:
#                        seating_capacity                                     \
#                                     min max      mean       std first last
# manufacturer fuel_type
# Audi         biodiesel                2  10  6.030683  2.583734     7   10
#              diesel                   2  10  5.960991  2.594637     4    3
#              electric                 2  10  5.999316  2.606017     5    8
#              ethanol                  2  10  6.021018  2.595082     5    4
#              gasoline                 2  10  6.022992  2.588995     3   10
# ...                                 ...  ..       ...       ...   ...  ...
# Volkswagen   electric                 2  10  6.017795  2.587015     3    5
#              ethanol                  2  10  6.016860  2.559153    10    6
#              gasoline                 2  10  5.999712  2.557221     6   10
#              hybrid                   2  10  6.048188  2.587311     9    4
# ...

# %%
df.groupby(['owner_district','manufacturer'])['selling_price'].sum()
# Out:
# owner_district  manufacturer
# east_bugesera   Audi            29995558.58
#                 BMW             29892772.16
#                 Chevrolet       29562609.10
#                 Ford            30231521.77
#                 Honda           28977513.34
#                                    ...
# west_rutsiro    Hyundai         29496673.68
#                 Mercedes        28613329.03
#                 Nissan          28695174.58
#                 Toyota          27557597.10
#                 Volkswagen      31122435.15
# Name: selling_price, Length: 300, dtype: float64

# %%
earnings_district = df.groupby(['owner_district','manufacturer'])['selling_price'].sum()
earnings_district.plot(kind="bar", figsize = (20,4))
# Out:
# <Axes: xlabel='owner_district,manufacturer'>

# %%
# Grouping and summing the selling and purchase prices by district
plt.figure(figsize=(20, 4))
selling_and_purchase_prices_by_district = df.groupby('owner_district')[['selling_price','proposed_purchase_price']].sum().sort_values(by='proposed_purchase_price')
colors = ['lightblue' if i % 2 == 0 else 'lightgreen' for i in range(len(selling_and_purchase_prices_by_district))]
bars=selling_and_purchase_prices_by_district.plot(kind='barh', color=colors)
plt.title("Money Earned from Vehicles by District", fontsize=20)
plt.ylabel("Districts", fontsize=15)
plt.xlabel("Purchase Price", fontsize=15)
plt.grid(color="green", linestyle="--", linewidth=0.5)
for bar in bars.patches:
    plt.text(bar.get_width(),bar.get_y() + bar.get_height() / 2, f'{int(bar.get_width()):,}', ha='left', va='center', fontsize=12, color='black')
plt.tight_layout() # Optional: Adjust layout to prevent clipping of labels
plt.show()

# %%
dem = df.groupby('owner_district')[['selling_price', 'proposed_purchase_price']].sum()
dem['profit'] = dem['proposed_purchase_price'] - dem['selling_price']
dem
bars = dem.plot(kind='barh', figsize=(20, 10))
for bar in bars.patches:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{int(bar.get_width()):,}', ha='left', va='center', fontsize=12, color='black')
plt.show()

# %%
plt.figure(figsize=(20, 4))
plt.pie(manufacturer_counts, labels=manufacturer_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Vehicle Manufacturers')
plt.axis('equal')
plt.show()

# %%
# Specify numeric columns (adjust based on the actual column names in your DataFrame)
numeric_columns = ['owner_age', 'selling_price', 'purchase_price', 'year', 'kilometers_driven']

# Check for missing columns and exclude them
existing_columns = [col for col in numeric_columns if col in df.columns]
missing_columns = [col for col in numeric_columns if col not in df.columns]

if missing_columns:
    print(f"The following columns are missing and will be excluded: {missing_columns}")

# Compute correlation matrix for existing numeric columns
if existing_columns:
    heatmap_data = df[existing_columns].corr()
    plt.figure(figsize=(20, 3))
    sns.heatmap(heatmap_data, cmap = 'BuPu', annot = True, linewidths= 0.5, fmt=".2f")
    plt.title("Correlation Heatmap")
    plt.show()
else:
    print("No valid numeric columns found for correlation analysis.")
# Out:
# The following columns are missing and will be excluded: ['purchase_price']

# %%
plt.figure(figsize=(20, 3))
sns.boxplot(data = df[['selling_price', 'proposed_purchase_price']], palette='Accent')
plt.title("Boxplot of Selling and Purchase Prices", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20, 5))
ax = sns.histplot(df['selling_price'], color='red',kde = True, bins=[5000,11000,25000,32000], alpha=0.5)

for p in ax.patches:
    count = int(p.get_height())
    ax.annotate(f'{count}', (p.get_x() + p.get_width() / 2, count), ha='center', va='bottom', fontsize=12, color='green', rotation=90)

plt.title("Histogram of Selling Price", fontsize=15)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_14968/2629004054.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(20, 5))
ax = sns.histplot(df['proposed_purchase_price'], color='blue', label='Proposed Purchase Price',kde=True, bins=[5000,14000,28000,42000,45500], alpha=0.5)
for p in ax.patches:
    count = int(p.get_height())
    ax.annotate(f'{count}', (p.get_x() + p.get_width() / 2, count), ha='center', va='bottom', fontsize=20, color='green', rotation='vertical')

plt.title("Histogram of Purchase Prices", fontsize=15)
plt.legend()
plt.show()

# %%
print('Correlation between selling_price and kilometers_driven:', df['selling_price'].corr(df['kilometers_driven']))
# Out:
# Correlation between selling_price and kilometers_driven: 0.6482410059776522

# %%
correlation = df['proposed_purchase_price'].corr(df['selling_price'])
print(correlation)
# Out:
# 0.9977638027210487

# %%
ax =df.groupby("manufacturer")[["selling_price","proposed_purchase_price"]].sum().plot(kind= "barh")
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.2f')  
    
plt.show()
